# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

sns.palplot(colors_dark)
sns.palplot(colors_green)
sns.palplot(colors_red)

# %%
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

# %%
X_train = []
y_train = []
image_size = 150
for i in labels:
    folderPath = os.path.join('/content/gdrive/MyDrive/DL/brain-tumor-classification-mri/Training', i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath, j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join('/content/gdrive/MyDrive/DL/brain-tumor-classification-mri','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:22<00:00, 36.58it/s]
# 100%|██████████| 395/395 [00:06<00:00, 63.93it/s]
# 100%|██████████| 822/822 [00:19<00:00, 42.22it/s]
# 100%|██████████| 827/827 [00:20<00:00, 40.97it/s]
# 100%|██████████| 100/100 [00:01<00:00, 57.55it/s]
# 100%|██████████| 105/105 [00:01<00:00, 74.88it/s]
# 100%|██████████| 115/115 [00:01<00:00, 60.63it/s]
# 100%|██████████| 74/74 [00:14<00:00,  5.12it/s]

# %%
k=0
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.62,x=0.4,alpha=0.8)
for i in labels:
    j=0
    while True :
        if y_train[j]==i:
            ax[k].imshow(X_train[j])
            ax[k].set_title(y_train[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
X_train.shape
# Out:
# (3264, 150, 150, 3)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 150, 150, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 150, 150, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 151, 151, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 75, 75, 32)           864       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 75, 75, 32)           128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 75, 75, 32)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 75, 75, 32)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 32)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 75, 75, 16)           512       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 75, 75, 16)           64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block2a_expand_conv (Conv2  (None, 75, 75, 96)           1536      ['block1a_project_bn[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 75, 75, 96)           384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 75, 75, 96)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 77, 77, 96)           0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 38, 38, 96)           864       ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 38, 38, 96)           384       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 38, 38, 96)           0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 96)                   0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 96)             0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 4)              388       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 96)             480       ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 38, 38, 96)           0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 38, 38, 24)           2304      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 38, 38, 24)           96        ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 38, 38, 144)          3456      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 38, 38, 144)          576       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 38, 38, 144)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 38, 38, 144)          1296      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 38, 38, 144)          576       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 38, 38, 144)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 144)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 38, 38, 144)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 38, 38, 24)           3456      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 38, 38, 24)           96        ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 38, 38, 24)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 38, 38, 24)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 38, 38, 144)          3456      ['block2b_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 38, 38, 144)          576       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 38, 38, 144)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 41, 41, 144)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 19, 19, 144)          3600      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 19, 19, 144)          576       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 19, 19, 144)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 144)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 19, 19, 144)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 19, 19, 40)           5760      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 19, 19, 40)           160       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 19, 19, 240)          9600      ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 19, 19, 240)          960       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 19, 19, 240)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 19, 19, 240)          6000      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 19, 19, 240)          960       ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 19, 19, 240)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 240)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 19, 19, 240)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 19, 19, 40)           9600      ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 19, 19, 40)           160       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 19, 19, 40)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 19, 19, 40)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 19, 19, 240)          9600      ['block3b_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 19, 19, 240)          960       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 19, 19, 240)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 21, 21, 240)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 10, 10, 240)          2160      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 10, 10, 240)          960       ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 10, 10, 240)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 240)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 10, 10, 240)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 10, 10, 80)           19200     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 10, 10, 80)           320       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 10, 10, 480)          38400     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 10, 10, 480)          1920      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 10, 10, 480)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 10, 10, 480)          4320      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 10, 10, 480)          1920      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 10, 10, 480)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 480)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 10, 10, 480)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 10, 10, 80)           38400     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 10, 10, 80)           320       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 10, 10, 80)           0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 10, 10, 80)           0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 10, 10, 480)          38400     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 10, 10, 480)          1920      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 10, 10, 480)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, 10, 10, 480)          4320      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, 10, 10, 480)          1920      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 10, 10, 480)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 480)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 10, 10, 480)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 10, 10, 80)           38400     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 10, 10, 80)           320       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 10, 10, 80)           0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 10, 10, 80)           0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 10, 10, 480)          38400     ['block4c_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 10, 10, 480)          1920      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 10, 10, 480)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv (DepthwiseC  (None, 10, 10, 480)          12000     ['block5a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5a_bn (BatchNormaliza  (None, 10, 10, 480)          1920      ['block5a_dwconv[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 10, 10, 480)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 480)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 10, 10, 480)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 10, 10, 112)          53760     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 10, 10, 112)          448       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 10, 10, 672)          75264     ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 10, 10, 672)          2688      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 10, 10, 672)          0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv (DepthwiseC  (None, 10, 10, 672)          16800     ['block5b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5b_bn (BatchNormaliza  (None, 10, 10, 672)          2688      ['block5b_dwconv[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 10, 10, 672)          0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 672)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 10, 10, 672)          0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 10, 10, 112)          75264     ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 10, 10, 112)          448       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 10, 10, 112)          0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 10, 10, 112)          0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 10, 10, 672)          75264     ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 10, 10, 672)          2688      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 10, 10, 672)          0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv (DepthwiseC  (None, 10, 10, 672)          16800     ['block5c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5c_bn (BatchNormaliza  (None, 10, 10, 672)          2688      ['block5c_dwconv[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 10, 10, 672)          0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 672)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 10, 10, 672)          0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 10, 10, 112)          75264     ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 10, 10, 112)          448       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 10, 10, 112)          0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 10, 10, 112)          0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2  (None, 10, 10, 672)          75264     ['block5c_add[0][0]']
#  D)
#
#  block6a_expand_bn (BatchNo  (None, 10, 10, 672)          2688      ['block6a_expand_conv[0][0]']
#  rmalization)
#
#  block6a_expand_activation   (None, 10, 10, 672)          0         ['block6a_expand_bn[0][0]']
#  (Activation)
#
#  block6a_dwconv_pad (ZeroPa  (None, 13, 13, 672)          0         ['block6a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block6a_dwconv (DepthwiseC  (None, 5, 5, 672)            16800     ['block6a_dwconv_pad[0][0]']
#  onv2D)
#
#  block6a_bn (BatchNormaliza  (None, 5, 5, 672)            2688      ['block6a_dwconv[0][0]']
#  tion)
#
#  block6a_activation (Activa  (None, 5, 5, 672)            0         ['block6a_bn[0][0]']
#  tion)
#
#  block6a_se_squeeze (Global  (None, 672)                  0         ['block6a_activation[0][0]']
#  AveragePooling2D)
#
# ...
#  block6b_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6b_se_squeeze[0][0]']
#  e)
#
#  block6b_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block6b_activation[0][0]',
#  y)                                                                  'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv  (None, 5, 5, 192)            221184    ['block6b_se_excite[0][0]']
#  2D)
#
#  block6b_project_bn (BatchN  (None, 5, 5, 192)            768       ['block6b_project_conv[0][0]']
#  ormalization)
#
#  block6b_drop (Dropout)      (None, 5, 5, 192)            0         ['block6b_project_bn[0][0]']
#
#  block6b_add (Add)           (None, 5, 5, 192)            0         ['block6b_drop[0][0]',
#                                                                      'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2  (None, 5, 5, 1152)           221184    ['block6b_add[0][0]']
#  D)
#
#  block6c_expand_bn (BatchNo  (None, 5, 5, 1152)           4608      ['block6c_expand_conv[0][0]']
#  rmalization)
#
#  block6c_expand_activation   (None, 5, 5, 1152)           0         ['block6c_expand_bn[0][0]']
#  (Activation)
#
#  block6c_dwconv (DepthwiseC  (None, 5, 5, 1152)           28800     ['block6c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6c_bn (BatchNormaliza  (None, 5, 5, 1152)           4608      ['block6c_dwconv[0][0]']
#  tion)
#
#  block6c_activation (Activa  (None, 5, 5, 1152)           0         ['block6c_bn[0][0]']
#  tion)
#
#  block6c_se_squeeze (Global  (None, 1152)                 0         ['block6c_activation[0][0]']
#  AveragePooling2D)
#
#  block6c_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6c_se_squeeze[0][0]']
#  e)
#
#  block6c_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6c_se_reshape[0][0]']
#
#  block6c_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6c_se_reduce[0][0]']
#
#  block6c_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block6c_activation[0][0]',
#  y)                                                                  'block6c_se_expand[0][0]']
#
#  block6c_project_conv (Conv  (None, 5, 5, 192)            221184    ['block6c_se_excite[0][0]']
#  2D)
#
#  block6c_project_bn (BatchN  (None, 5, 5, 192)            768       ['block6c_project_conv[0][0]']
#  ormalization)
#
#  block6c_drop (Dropout)      (None, 5, 5, 192)            0         ['block6c_project_bn[0][0]']
#
#  block6c_add (Add)           (None, 5, 5, 192)            0         ['block6c_drop[0][0]',
#                                                                      'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2  (None, 5, 5, 1152)           221184    ['block6c_add[0][0]']
#  D)
#
#  block6d_expand_bn (BatchNo  (None, 5, 5, 1152)           4608      ['block6d_expand_conv[0][0]']
#  rmalization)
#
#  block6d_expand_activation   (None, 5, 5, 1152)           0         ['block6d_expand_bn[0][0]']
#  (Activation)
#
#  block6d_dwconv (DepthwiseC  (None, 5, 5, 1152)           28800     ['block6d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6d_bn (BatchNormaliza  (None, 5, 5, 1152)           4608      ['block6d_dwconv[0][0]']
#  tion)
#
#  block6d_activation (Activa  (None, 5, 5, 1152)           0         ['block6d_bn[0][0]']
#  tion)
#
#  block6d_se_squeeze (Global  (None, 1152)                 0         ['block6d_activation[0][0]']
#  AveragePooling2D)
#
#  block6d_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6d_se_squeeze[0][0]']
#  e)
#
#  block6d_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block6d_activation[0][0]',
#  y)                                                                  'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv  (None, 5, 5, 192)            221184    ['block6d_se_excite[0][0]']
#  2D)
#
#  block6d_project_bn (BatchN  (None, 5, 5, 192)            768       ['block6d_project_conv[0][0]']
#  ormalization)
#
#  block6d_drop (Dropout)      (None, 5, 5, 192)            0         ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)           (None, 5, 5, 192)            0         ['block6d_drop[0][0]',
#                                                                      'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 5, 5, 1152)           221184    ['block6d_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 5, 5, 1152)           4608      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 5, 5, 1152)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 5, 5, 1152)           10368     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 5, 5, 1152)           4608      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 5, 5, 1152)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1152)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 5, 5, 320)            368640    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 5, 5, 320)            1280      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  top_conv (Conv2D)           (None, 5, 5, 1280)           409600    ['block7a_project_bn[0][0]']
#
#  top_bn (BatchNormalization  (None, 5, 5, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 5, 5, 1280)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 1280)                 0         ['top_activation[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 4)                    5124      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 4054695 (15.47 MB)
# Trainable params: 4012672 (15.31 MB)
# Non-trainable params: 42023 (164.16 KB)
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %% [markdown]
# ---

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.8161
# Epoch 1: val_accuracy improved from -inf to 0.85714, saving model to effnet.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 83/83 [==============================] - 56s 182ms/step - loss: 0.4803 - accuracy: 0.8161 - val_loss: 0.4218 - val_accuracy: 0.8571 - lr: 0.0010
# Epoch 2/50
# 83/83 [==============================] - ETA: 0s - loss: 0.2042 - accuracy: 0.9304
# Epoch 2: val_accuracy improved from 0.85714 to 0.90136, saving model to effnet.h5
# 83/83 [==============================] - 11s 137ms/step - loss: 0.2042 - accuracy: 0.9304 - val_loss: 0.3151 - val_accuracy: 0.9014 - lr: 0.0010
# Epoch 3/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9603
# Epoch 3: val_accuracy did not improve from 0.90136
# 83/83 [==============================] - 11s 130ms/step - loss: 0.1234 - accuracy: 0.9603 - val_loss: 0.3135 - val_accuracy: 0.8980 - lr: 0.0010
# Epoch 4/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9675
# Epoch 4: val_accuracy improved from 0.90136 to 0.93197, saving model to effnet.h5
# 83/83 [==============================] - 12s 139ms/step - loss: 0.0982 - accuracy: 0.9675 - val_loss: 0.2133 - val_accuracy: 0.9320 - lr: 0.0010
# Epoch 5/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.9724
# Epoch 5: val_accuracy did not improve from 0.93197
# 83/83 [==============================] - 11s 129ms/step - loss: 0.0797 - accuracy: 0.9724 - val_loss: 0.2924 - val_accuracy: 0.9116 - lr: 0.0010
# Epoch 6/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 0.9712
# Epoch 6: val_accuracy improved from 0.93197 to 0.93537, saving model to effnet.h5
# 83/83 [==============================] - 11s 139ms/step - loss: 0.1029 - accuracy: 0.9712 - val_loss: 0.2642 - val_accuracy: 0.9354 - lr: 0.0010
# Epoch 7/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9845
# Epoch 7: val_accuracy did not improve from 0.93537
# 83/83 [==============================] - 11s 131ms/step - loss: 0.0471 - accuracy: 0.9845 - val_loss: 0.1817 - val_accuracy: 0.9286 - lr: 0.0010
# Epoch 8/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9894
# Epoch 8: val_accuracy did not improve from 0.93537
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 [==============================] - 11s 131ms/step - loss: 0.0329 - accuracy: 0.9894 - val_loss: 0.2186 - val_accuracy: 0.9320 - lr: 0.0010
# Epoch 9/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9936
# Epoch 9: val_accuracy improved from 0.93537 to 0.96259, saving model to effnet.h5
# 83/83 [==============================] - 12s 143ms/step - loss: 0.0203 - accuracy: 0.9936 - val_loss: 0.1066 - val_accuracy: 0.9626 - lr: 3.0000e-04
# Epoch 10/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9977
# Epoch 10: val_accuracy improved from 0.96259 to 0.96939, saving model to effnet.h5
# 83/83 [==============================] - 12s 142ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0794 - val_accuracy: 0.9694 - lr: 3.0000e-04
# Epoch 11/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9981
# Epoch 11: val_accuracy did not improve from 0.96939
# 83/83 [==============================] - 11s 130ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.0796 - val_accuracy: 0.9694 - lr: 3.0000e-04
# Epoch 12/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9992
# Epoch 12: val_accuracy improved from 0.96939 to 0.97619, saving model to effnet.h5
# 83/83 [==============================] - 12s 140ms/step - loss: 0.0046 - accuracy: 0.9992 - val_loss: 0.0878 - val_accuracy: 0.9762 - lr: 3.0000e-04
# Epoch 13/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9985
# Epoch 13: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0893 - val_accuracy: 0.9694 - lr: 3.0000e-04
# Epoch 14/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9985
# Epoch 14: val_accuracy did not improve from 0.97619
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0786 - val_accuracy: 0.9728 - lr: 3.0000e-04
# Epoch 15/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9981
# Epoch 15: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.0813 - val_accuracy: 0.9762 - lr: 9.0000e-05
# Epoch 16/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9992
# Epoch 16: val_accuracy did not improve from 0.97619
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0806 - val_accuracy: 0.9762 - lr: 9.0000e-05
# Epoch 17/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9989
# Epoch 17: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 131ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0792 - val_accuracy: 0.9728 - lr: 2.7000e-05
# Epoch 18/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9992
# Epoch 18: val_accuracy did not improve from 0.97619
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 83/83 [==============================] - 11s 132ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0806 - val_accuracy: 0.9728 - lr: 2.7000e-05
# Epoch 19/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9989
# Epoch 19: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0805 - val_accuracy: 0.9728 - lr: 8.1000e-06
# Epoch 20/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9985
# Epoch 20: val_accuracy did not improve from 0.97619
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0806 - val_accuracy: 0.9728 - lr: 8.1000e-06
# Epoch 21/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9981
# Epoch 21: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0792 - val_accuracy: 0.9728 - lr: 2.4300e-06
# Epoch 22/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9981
# Epoch 22: val_accuracy did not improve from 0.97619
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0040 - accuracy: 0.9981 - val_loss: 0.0781 - val_accuracy: 0.9728 - lr: 2.4300e-06
# Epoch 23/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9992
# Epoch 23: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.0783 - val_accuracy: 0.9728 - lr: 7.2900e-07
# Epoch 24/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9989
# Epoch 24: val_accuracy did not improve from 0.97619
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0788 - val_accuracy: 0.9728 - lr: 7.2900e-07
# Epoch 25/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9992
# Epoch 25: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 135ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0787 - val_accuracy: 0.9728 - lr: 2.1870e-07
# Epoch 26/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9981
# Epoch 26: val_accuracy did not improve from 0.97619
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0046 - accuracy: 0.9981 - val_loss: 0.0788 - val_accuracy: 0.9728 - lr: 2.1870e-07
# Epoch 27/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9992
# Epoch 27: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0038 - accuracy: 0.9992 - val_loss: 0.0785 - val_accuracy: 0.9728 - lr: 6.5610e-08
# Epoch 28/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9981
# Epoch 28: val_accuracy did not improve from 0.97619
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0037 - accuracy: 0.9981 - val_loss: 0.0785 - val_accuracy: 0.9728 - lr: 6.5610e-08
# Epoch 29/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0786 - val_accuracy: 0.9728 - lr: 1.9683e-08
# Epoch 30/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 30: val_accuracy did not improve from 0.97619
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0784 - val_accuracy: 0.9728 - lr: 1.9683e-08
# Epoch 31/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9989
# Epoch 31: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0784 - val_accuracy: 0.9728 - lr: 5.9049e-09
# Epoch 32/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9985
# Epoch 32: val_accuracy did not improve from 0.97619
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.7714700373261393e-09.
# 83/83 [==============================] - 11s 135ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.0784 - val_accuracy: 0.9728 - lr: 5.9049e-09
# Epoch 33/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9996
# Epoch 33: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.0783 - val_accuracy: 0.9728 - lr: 1.7715e-09
# Epoch 34/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9981
# Epoch 34: val_accuracy did not improve from 0.97619
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 5.314410245205181e-10.
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0042 - accuracy: 0.9981 - val_loss: 0.0785 - val_accuracy: 0.9728 - lr: 1.7715e-09
# Epoch 35/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9989
# Epoch 35: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0782 - val_accuracy: 0.9728 - lr: 5.3144e-10
# Epoch 36/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992
# Epoch 36: val_accuracy did not improve from 0.97619
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.5943230069481729e-10.
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0785 - val_accuracy: 0.9728 - lr: 5.3144e-10
# Epoch 37/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9992
# Epoch 37: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0784 - val_accuracy: 0.9728 - lr: 1.5943e-10
# Epoch 38/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9985
# Epoch 38: val_accuracy did not improve from 0.97619
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.7829690208445185e-11.
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0784 - val_accuracy: 0.9728 - lr: 1.5943e-10
# Epoch 39/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 39: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 135ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0780 - val_accuracy: 0.9728 - lr: 4.7830e-11
# Epoch 40/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9989
# Epoch 40: val_accuracy did not improve from 0.97619
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.434890747886719e-11.
# 83/83 [==============================] - 11s 136ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0785 - val_accuracy: 0.9728 - lr: 4.7830e-11
# Epoch 41/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9992
# Epoch 41: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 135ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0779 - val_accuracy: 0.9728 - lr: 1.4349e-11
# Epoch 42/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9985
# Epoch 42: val_accuracy did not improve from 0.97619
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.304672243660157e-12.
# 83/83 [==============================] - 11s 135ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0779 - val_accuracy: 0.9728 - lr: 1.4349e-11
# Epoch 43/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9992
# Epoch 43: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 135ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0780 - val_accuracy: 0.9728 - lr: 4.3047e-12
# Epoch 44/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 44: val_accuracy did not improve from 0.97619
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.2914016210563428e-12.
# 83/83 [==============================] - 11s 135ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0782 - val_accuracy: 0.9728 - lr: 4.3047e-12
# Epoch 45/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9985
# Epoch 45: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0792 - val_accuracy: 0.9728 - lr: 1.2914e-12
# Epoch 46/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 46: val_accuracy did not improve from 0.97619
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.874204993273289e-13.
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0782 - val_accuracy: 0.9728 - lr: 1.2914e-12
# Epoch 47/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9996
# Epoch 47: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.0791 - val_accuracy: 0.9728 - lr: 3.8742e-13
# Epoch 48/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9996
# Epoch 48: val_accuracy did not improve from 0.97619
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.162261530508052e-13.
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.0790 - val_accuracy: 0.9728 - lr: 3.8742e-13
# Epoch 49/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9989
# Epoch 49: val_accuracy did not improve from 0.97619
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0791 - val_accuracy: 0.9728 - lr: 1.1623e-13
# Epoch 50/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9992
# Epoch 50: val_accuracy did not improve from 0.97619
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 3.4867844288938296e-14.
# 83/83 [==============================] - 11s 134ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0783 - val_accuracy: 0.9728 - lr: 1.1623e-13

# %%
filterwarnings('ignore')

epochs = [i for i in range(50)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label ='Training Loss')
ax[1].plot(epochs, val_loss, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 11/11 [==============================] - 3s 121ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        93
#            1       0.96      1.00      0.98        51
#            2       0.97      0.98      0.97        96
#            3       0.99      0.99      0.99        87
#
#     accuracy                           0.98       327
#    macro avg       0.98      0.98      0.98       327
# weighted avg       0.98      0.98      0.98       327

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,
           cmap=colors_green[::-1],alpha=0.7,linewidths=2,linecolor=colors_dark[3])
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.92,x=0.28,alpha=0.8)

plt.show()

# %%
def img_pred(upload):
    for name, file_info in uploader.value.items():
        img = Image.open(io.BytesIO(file_info['content']))
    opencvImage = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
    img = cv2.resize(opencvImage,(150,150))
    img = img.reshape(1,150,150,3)
    p = model.predict(img)
    p = np.argmax(p,axis=1)[0]

    if p==0:
        p='Glioma Tumor'
    elif p==1:
        print('The model predicts that there is no tumor')
    elif p==2:
        p='Meningioma Tumor'
    else:
        p='Pituitary Tumor'

    if p!=1:
        print(f'The Model predicts that it is a {p}')

# %%
uploader = widgets.FileUpload()
display(uploader)
# Out:
# FileUpload(value={}, description='Upload')

# %%
button = widgets.Button(description='Predict')
out = widgets.Output()
def on_button_clicked(_):
    with out:
        clear_output()
        try:
            img_pred(uploader)

        except:
            print('No Image Uploaded/Invalid Image File')
button.on_click(on_button_clicked)
widgets.VBox([button,out])
# Out:
# VBox(children=(Button(description='Predict', style=ButtonStyle()), Output()))
